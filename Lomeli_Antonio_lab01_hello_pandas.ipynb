# %% [markdown]
# ### 🔧 **Setup**

# %%
# Install required libraries
# !pip install pandas numpy

# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📍 **Section 1: Series - One-Dimensional Data**

# %%
# Creating a Series
x = 20.0
print(type(x))
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# <class 'float'>
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ### 📘 What this does:
# * `pd.Series(...)` creates a one-dimensional array-like object.
# * `np.nan` stands for "Not a Number", a missing value.

# %% [markdown]
# ### ✏️ Exercise 1:
# * Create your own Series with names of fruits.
# * Include a missing value using `np.nan`.

# %%
# Your code here:
my_series = pd.Series(['apple','banana','cantaloupe','dragonfruit','blueberry','blackberry',np.nan])
print(my_series)
# Out:
# 0          apple
# 1         banana
# 2     cantaloupe
# 3    dragonfruit
# 4      blueberry
# 5     blackberry
# 6            NaN
# dtype: object

# %% [markdown]
# ## 📍 **Section 2: DataFrame - Two-Dimensional Data**
#
# ✅ 1. Tabular Data Representation
# Mimics a spreadsheet or SQL table: rows + labeled columns.
#
# Makes data easy to read, access, and interpret.
#
# ✅ 2. Labeled Indexing
# You can access data using row/column labels, not just numbers.
#
# This improves clarity and reduces errors in complex analyses.

# %%
# Create a datetime index
dates = pd.date_range("20220101", periods=6)
# Create a DataFrame with random numbers
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.508557 -0.387580 -0.668807 -1.451306
# 2022-01-02 -0.330439  2.006075 -0.354158  0.083325
# 2022-01-03 -0.321763  0.820135  0.115500  0.269255
# 2022-01-04 -1.175726  0.231000  0.804117 -0.508980
# 2022-01-05 -0.970453 -1.602637 -1.440191 -0.194788
# 2022-01-06  0.651311 -0.287415  1.448214 -1.395705

# %% [markdown]
# ### 📘 Explanation:
# * `date_range()` creates dates.
# * `np.random.randn()` creates random data.
# * `DataFrame(...)` builds a table from the array.

# %%
dates = pd.date_range("2025", periods = 12)

c = "22"+"3"
print(dates)
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10', '2025-01-11', '2025-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ### ✏️ Exercise 2:
# * Create a DataFrame with 5 rows, 3 columns (`X`, `Y`, `Z`), and use your own numbers.

# %%
# Your code here
id = [1,2,3,4,5]
names = ['Anna','Bonna','Calla','Dana']

df2 = pd.DataFrame(np.random.randn(5, 3), index=id, columns=list("xyz"))
df2
# Out:
#           x         y         z
# 1 -0.019078 -0.791390  1.236592
# 2  0.794084  2.470696  1.080888
# 3 -0.211572 -2.267167 -0.021198
# 4  1.414240  0.312732 -1.887397
# 5 -0.450764  0.477025  1.121545

# %% [markdown]
# ## 📍 **Section 3: DataFrame from a Dictionary**

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20220101"),
    "C": pd.Series([1, 2, 3, 4], dtype="float32"),
    "D": np.array([3] * 4, dtype="int32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo",
})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2022-01-01  1.0  3   test  foo
# 1  1.0 2022-01-01  2.0  3  train  foo
# 2  1.0 2022-01-01  3.0  3   test  foo
# 3  1.0 2022-01-01  4.0  3  train  foo

# %%
# To access one column in the df2
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %% [markdown]
# ### 📘 Explanation:
# You can pass a Python dictionary to create a more structured and labeled dataset.

# %% [markdown]
# ### ✏️ Exercise 3:
# * Create a DataFrame with columns for your `name`, `age`, and `student status (True/False)`.

# %%
# Your code here
students = pd.DataFrame({
    # write the structure here
    'Name':pd.Series(['Tony','Andrew','Ethan','John']),
    'Age':pd.Series(['19','21','18','19']),
    'Student Status':pd.Series(['True','True','False','True'])
})
students
# Out:
#      Name Age Student Status
# 0    Tony  19           True
# 1  Andrew  21           True
# 2   Ethan  18          False
# 3    John  19           True

# %% [markdown]
# ## 📍 **Section 4: Inspecting Data**

# %%
# View top and bottom rows
print(df.head())
print(df.tail())

# %%
# Show index and column names
print(df.index)
print(df.columns)

# %%
# Convert to NumPy array (for computation)
df.to_numpy()

# %%
# Check column data types
df2.dtypes

# %% [markdown]
# ### ✏️ Exercise 4:
# * Use `.head()` and `.tail()` to inspect your own DataFrame from Exercise 3.

# %%
students.head()
students.tail()
# Out:
#      Name Age Student Status
# 0    Tony  19           True
# 1  Andrew  21           True
# 2   Ethan  18          False
# 3    John  19           True

# %% [markdown]
# ## 📍 **Section 5: Summary Statistics**

# %%
# Summary of statistics
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.273085  0.129930 -0.015887 -0.533033
# std    0.744609  1.220680  1.039484  0.738374
# min   -1.175726 -1.602637 -1.440191 -1.451306
# 25%   -0.810450 -0.362539 -0.590145 -1.174024
# 50%   -0.326101 -0.028208 -0.119329 -0.351884
# 75%    0.300977  0.672851  0.631963  0.013797
# max    0.651311  2.006075  1.448214  0.269255

# %%
# Transpose rows and columns
df.T
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06
# A    0.508557   -0.330439   -0.321763   -1.175726   -0.970453    0.651311
# B   -0.387580    2.006075    0.820135    0.231000   -1.602637   -0.287415
# C   -0.668807   -0.354158    0.115500    0.804117   -1.440191    1.448214
# D   -1.451306    0.083325    0.269255   -0.508980   -0.194788   -1.395705

# %%
# Sort by column names
df.sort_index(axis=1, ascending=False)

# %%
# Sort by values in a specific column
df.sort_values(by="C")

# %% [markdown]
# ### ✏️ Exercise 5:
# * Add a new column `Score` to your DataFrame and sort it.

# %%
students['Score'] = pd.Series(['99','83','93','88'])

students_sorted = students.sort_values(by='Score', ascending = False)
students_sorted
# Out:
#      Name Age Student Status Score
# 0    Tony  19           True    99
# 2   Ethan  18          False    93
# 3    John  19           True    88
# 1  Andrew  21           True    83

# %% [markdown]
# ## 📍 **Section 6: Selecting Columns**

# %%
# Select a column using bracket notation
df["A"]
# Out:
# 2022-01-01    0.508557
# 2022-01-02   -0.330439
# 2022-01-03   -0.321763
# 2022-01-04   -1.175726
# 2022-01-05   -0.970453
# 2022-01-06    0.651311
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# ### ✏️ Exercise 6:
# * Print the column `A` and plot it using `.plot()` (Optional: if you're in Colab or Jupyter)

# %%
df['A'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## ✅ **Final Task (Mini Project)**:
# Use what you've learned to:
# * Create a DataFrame with 5 students and their grades in Math, Science, and English.
# * Calculate the average for each student.
# * Sort the DataFrame by average grade.
# * Display summary statistics.

# %%
grades_df = pd.DataFrame({
    # write the structure here
    'Name':pd.Series(['Ben','Daniel','Alejandro','David','Emanuel']),
    'Math':pd.Series([98,95,84,83,85]),
    'Science':pd.Series([97,94,79,81,88]),
    'English':pd.Series([94,98,91,84,89])
})
grades_df

avg_grades = (grades_df['Math'] + grades_df['Science'] + grades_df['English'])
grades_df['Average'] = avg_grades / 3
print(grades_df)

print(grades_df.sort_values(by='Average', ascending = False))
grades_df.describe()
# Out:
#         Name  Math  Science  English    Average
# 0        Ben    98       97       94  96.333333
# 1     Daniel    95       94       98  95.666667
# 2  Alejandro    84       79       91  84.666667
# 3      David    83       81       84  82.666667
# 4    Emanuel    85       88       89  87.333333
#         Name  Math  Science  English    Average
# 0        Ben    98       97       94  96.333333
# 1     Daniel    95       94       98  95.666667
# 4    Emanuel    85       88       89  87.333333
# 2  Alejandro    84       79       91  84.666667
# 3      David    83       81       84  82.666667
#             Math    Science    English    Average
# count   5.000000   5.000000   5.000000   5.000000
# mean   89.000000  87.800000  91.200000  89.333333
# std     6.964194   7.854935   5.263079   6.311365
# min    83.000000  79.000000  84.000000  82.666667
# 25%    84.000000  81.000000  89.000000  84.666667
# 50%    85.000000  88.000000  91.000000  87.333333
# ...
